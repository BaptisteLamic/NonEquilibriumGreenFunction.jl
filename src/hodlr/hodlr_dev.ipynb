# %%
using Revise

# %%
using LowRankApprox
m = randn(1000,12)*randn(12,1000) 
F =  psvdfact(LinearOperator(m), sketch=:sub)
# Out:
# ┌ Warning: invalid sketch method; using "randn"
# └ @ LowRankApprox E:\julia_depot\baptiste\packages\LowRankApprox\rdCCd\src\LowRankApprox.jl:145
# ...
