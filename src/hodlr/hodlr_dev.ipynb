# %%
using Revise
using BenchmarkTools
using TestItems
using AppleAccelerate
includet("./hodlr.jl")

# %%
Threads.nthreads()
# Out:
# 6

# %%
using LinearAlgebra
using LowRankApprox
using StaticArrays
using ACAFact
